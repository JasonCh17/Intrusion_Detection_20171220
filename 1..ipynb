# %%
import pandas 
from numpy import array
import matplotlib.pyplot as plt
gv={'rank_test_score': array([4, 2, 1, 3]), 
 'split4_train_score': array([ 0.99999235,  1.        ,  1.        ,  1.        ]), 
 'split7_test_score': array([ 0.99960972,  0.99949494,  0.99956381,  0.99944902]), 
 'split5_test_score': array([ 0.99988522,  0.99988522,  0.99993113,  0.99988522]),
 'split1_train_score': array([ 0.9999847 ,  0.99999745,  1.        ,  1.        ]),
 'split9_train_score': array([ 0.99999745,  1.        ,  1.        ,  1.        ]),
 'split8_train_score': array([ 0.99999235,  1.        ,  1.        ,  1.        ]), 
 'split2_test_score': array([ 0.99990818,  0.99995409,  0.99990818,  0.99990818]), 
 'split8_test_score': array([ 0.9996786 ,  0.99965564,  0.99960972,  0.99965564]), 
 'std_test_score': array([ 0.00016362,  0.00015738,  0.00014228,  0.00016388]), 
 'std_train_score': array([  4.08120465e-06,   7.65226086e-07,   0.00000000e+00,0.00000000e+00]), 
 'params': [{'n_estimators': 10}, {'n_estimators': 40}, {'n_estimators': 70}, {'n_estimators': 100}], 
 'split7_train_score': array([ 0.9999949,  1.       ,  1.       ,  1.       ]), 
 'split0_train_score': array([ 0.9999949,  1.       ,  1.       ,  1.       ]), 
 'split9_test_score': array([ 0.99974746,  0.99979338,  0.99983929,  0.99983929]),
 'mean_test_score': array([ 0.99974748,  0.99979339,  0.99980946,  0.9997888 ]),
 'split0_test_score': array([ 0.99947203,  0.99956385,  0.99965567,  0.99958681]), 
 'split6_train_score': array([ 0.99999745,  1.        ,  1.        ,  1.        ]), 
 'mean_score_time': array([ 0.09395158,  0.23768473,  0.38197207,  0.53224449]), 
 'std_score_time': array([ 0.00200694,  0.00419584,  0.00579572,  0.01527497]), 
'mean_fit_time': array([  5.62369392,  20.64177463,  35.70401285,  50.28675587]),
'std_fit_time': array([ 0.13857343,  0.2137341 ,  0.21835488,  0.39927251]), 
'split5_train_score': array([ 0.99999745,  1.        ,  1.        ,  1.        ]), 
'split2_train_score': array([ 1.,  1.,  1.,  1.]), 
'split6_test_score': array([ 0.99979338,  0.99988521,  0.99990817,  0.99986226]),
'mean_train_score': array([ 0.99999439,  0.99999974,  1.        ,  1.        ]), 
'split4_test_score': array([ 0.99951791,  0.9998393 ,  0.99977043,  0.99977043]), 
'split3_test_score': array([ 0.99990817,  0.99997704,  0.99995409,  0.99997704]), 
'split3_train_score': array([ 0.99999235,  1.        ,  1.        ,  1.        ]),
'split1_test_score': array([ 0.99995409,  0.99988522,  0.99995409,  0.99995409])} 

{'n_estimators': 70} 
0.999809459531
# Out:
# 0.999809459531

# %%
# gv.keys()
# gv.values()
gv['mean_test_score']
# Out:
# array([ 0.99974748,  0.99979339,  0.99980946,  0.9997888 ])

# %%
param_test = {'n_estimators':range(10,101,30)}

# %%
plt.plot(param_test['n_estimators'],gv['mean_test_score'])
plt.show()
